# %% [markdown]
# <a href="https://colab.research.google.com/github/myname-baskaran/AI-JOURNEY/blob/main/Day02_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 2 - Python Fundamentals

# %%
monthly_salary = 6500

# %%
months = 12

# %%
annual_salary = monthly_salary * months

# %%
print("annual salary",annual_salary);
# Out:
# annual salary 78000

# %%
investment = 1000
years = 5
interest_rate = 1.08

# %%
future_value = investment * (interest_rate ** years)

# %%
print(future_value);
# Out:
# 1469.3280768000006

# %%
print ("after",years,"years:",future_value)
# Out:
# after 5 years: 1469.3280768000006

# %%
name = 'baskaran'

# %%
print('future ai engineer:',name);
# Out:
# future ai engineer: baskaran

# %%
months1 = 11
days1 = 30
days_for_ord = months1 * days1

# %%
print('days for ORD:',days_for_ord,'days');
# Out:
# days for ORD: 330 days

# %%
print(type(monthly_salary));
print(type(investment));
print(type(interest_rate));
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
