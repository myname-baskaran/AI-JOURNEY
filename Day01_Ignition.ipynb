# %% [markdown]
# <a href="https://colab.research.google.com/github/myname-baskaran/AI-JOURNEY/blob/main/Day01_Ignition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Day 1. Operation ORD begins.")
# Out:
# Day 1. Operation ORD begins.

# %%
monthly_target = 6500
months_to_ord = 11
print("Sessions to greatness:", months_to_ord * 30)
# Out:
# Sessions to greatness: 330
